# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Cursor

# %%
pad = pd.read_csv('pads_data.csv')
file_path = 'pads_data.csv'

# %%
pad
# Out:
#             Product Name Date of Expiry  Quantity  Quantity Used  \
# 0    Organic Cotton Pads     2024-08-12       124             75
# 1    Organic Cotton Pads     2024-10-26        85             52
# 2           Regular Pads     2024-11-19       179            104
# 3    Organic Cotton Pads     2024-11-24       113             71
# 4           Panty Liners     2024-12-26        73             26
# 5           Panty Liners     2025-01-09        62              9
# 6   Super Absorbent Pads     2025-01-26        53              8
# 7   Super Absorbent Pads     2025-02-03        50             17
# 8    Organic Cotton Pads     2025-02-09       187            166
# 9   Super Absorbent Pads     2025-02-11        66              2
# 10          Regular Pads     2025-02-17       123             23
# 11        Overnight Pads     2025-02-23        81             23
# 12          Regular Pads     2025-03-16       115             43
# ...

# %%
pad['Completely used'] = [
    "No", "Yes", "Yes", "Yes", "No", "No", "No", "No", "Yes", "Yes",
    "No", "Yes", "No", "No", "No", "Yes", "No", "No", "Yes", "No",
    "Yes", "No", "No", "No", "No", "Yes", "Yes", "No", "No", "Yes",
    "Yes", "No", "No", "Yes", "Yes", "Yes", "Yes", "No", "Yes", "No",
    "Yes", "No", "No", "No", "Yes", "Yes", "Yes", "No", "No", "No"
]

# %%
pad
# Out:
#             Product Name Date of Expiry  Quantity  Quantity Used  \
# 0    Organic Cotton Pads     2024-08-12       124             75
# 1    Organic Cotton Pads     2024-10-26        85             52
# 2           Regular Pads     2024-11-19       179            104
# 3    Organic Cotton Pads     2024-11-24       113             71
# 4           Panty Liners     2024-12-26        73             26
# 5           Panty Liners     2025-01-09        62              9
# 6   Super Absorbent Pads     2025-01-26        53              8
# 7   Super Absorbent Pads     2025-02-03        50             17
# 8    Organic Cotton Pads     2025-02-09       187            166
# 9   Super Absorbent Pads     2025-02-11        66              2
# 10          Regular Pads     2025-02-17       123             23
# 11        Overnight Pads     2025-02-23        81             23
# 12          Regular Pads     2025-03-16       115             43
# ...

# %%
pad.columns
# Out:
# Index(['Product Name', 'Date of Expiry', 'Quantity', 'Quantity Used',
#        'Quantity Left', 'Donated by NGO', 'Completely used'],
#       dtype='object')

# %%
df = pad.sort_values(by='Date of Expiry', ascending=True)

# %%
df
# Out:
#             Product Name Date of Expiry  Quantity  Quantity Used  \
# 0    Organic Cotton Pads     2024-08-12       124             75
# 1    Organic Cotton Pads     2024-10-26        85             52
# 2           Regular Pads     2024-11-19       179            104
# 3    Organic Cotton Pads     2024-11-24       113             71
# 4           Panty Liners     2024-12-26        73             26
# 5           Panty Liners     2025-01-09        62              9
# 6   Super Absorbent Pads     2025-01-26        53              8
# 7   Super Absorbent Pads     2025-02-03        50             17
# 8    Organic Cotton Pads     2025-02-09       187            166
# 9   Super Absorbent Pads     2025-02-11        66              2
# 10          Regular Pads     2025-02-17       123             23
# 11        Overnight Pads     2025-02-23        81             23
# 12          Regular Pads     2025-03-16       115             43
# ...

# %%
pad = df.reset_index(drop=True)

# %%
pad
# Out:
#             Product Name Date of Expiry  Quantity  Quantity Used  \
# 0    Organic Cotton Pads     2024-08-12       124             75
# 1    Organic Cotton Pads     2024-10-26        85             52
# 2           Regular Pads     2024-11-19       179            104
# 3    Organic Cotton Pads     2024-11-24       113             71
# 4           Panty Liners     2024-12-26        73             26
# 5           Panty Liners     2025-01-09        62              9
# 6   Super Absorbent Pads     2025-01-26        53              8
# 7   Super Absorbent Pads     2025-02-03        50             17
# 8    Organic Cotton Pads     2025-02-09       187            166
# 9   Super Absorbent Pads     2025-02-11        66              2
# 10          Regular Pads     2025-02-17       123             23
# 11        Overnight Pads     2025-02-23        81             23
# 12          Regular Pads     2025-03-16       115             43
# ...

# %%
pad
# Out:
#             Product Name Date of Expiry  Quantity  Quantity Used  \
# 0    Organic Cotton Pads     2024-08-12       124             75
# 1    Organic Cotton Pads     2024-10-26        85             52
# 2           Regular Pads     2024-11-19       179            104
# 3    Organic Cotton Pads     2024-11-24       113             71
# 4           Panty Liners     2024-12-26        73             26
# 5           Panty Liners     2025-01-09        62              9
# 6   Super Absorbent Pads     2025-01-26        53              8
# 7   Super Absorbent Pads     2025-02-03        50             17
# 8    Organic Cotton Pads     2025-02-09       187            166
# 9   Super Absorbent Pads     2025-02-11        66              2
# 10          Regular Pads     2025-02-17       123             23
# 11        Overnight Pads     2025-02-23        81             23
# 12          Regular Pads     2025-03-16       115             43
# ...

# %%
df = pd.read_csv("pads_data.csv")

# %%
df
# Out:
#             Product Name Date of Expiry  Quantity  Quantity Used  \
# 0    Organic Cotton Pads     2024-08-12       124             75
# 1    Organic Cotton Pads     2024-10-26        85             52
# 2           Regular Pads     2024-11-19       179            104
# 3    Organic Cotton Pads     2024-11-24       113             71
# 4           Panty Liners     2024-12-26        73             26
# 5           Panty Liners     2025-01-09        62              9
# 6   Super Absorbent Pads     2025-01-26        53              8
# 7   Super Absorbent Pads     2025-02-03        50             17
# 8    Organic Cotton Pads     2025-02-09       187            166
# 9   Super Absorbent Pads     2025-02-11        66              2
# 10          Regular Pads     2025-02-17       123             23
# 11        Overnight Pads     2025-02-23        81             23
# 12          Regular Pads     2025-03-16       115             43
# ...

# %%
df.columns
# Out:
# Index(['Product Name', 'Date of Expiry', 'Quantity', 'Quantity Used',
#        'Quantity Left', 'Donated by NGO', 'Completely used'],
#       dtype='object')

# %%
plt.bar(df['Quantity'],df['Product Name'])
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.pie(df['Quantity'].head(10),labels=df['Product Name'].head(10), autopct="%0.1f%%")
# plt.legend(loc= 8)
plt.show()

# %%
plt.plot(df['Quantity'].head(5).cumsum(),df['Product Name'].head(5).cumsum())
plt.xticks(rotation = 20)
plt.plot(df['Quantity Used'].head(5).cumsum(),df['Product Name'].head(5).cumsum())
plt.plot(df['Quantity Left'].head(5).cumsum(),df['Product Name'].head(5).cumsum())
plt.show()

# %%
df
# Out:
#             Product Name Date of Expiry  Quantity  Quantity Used  \
# 0    Organic Cotton Pads     2024-08-12       124             75
# 1    Organic Cotton Pads     2024-10-26        85             52
# 2           Regular Pads     2024-11-19       179            104
# 3    Organic Cotton Pads     2024-11-24       113             71
# 4           Panty Liners     2024-12-26        73             26
# 5           Panty Liners     2025-01-09        62              9
# 6   Super Absorbent Pads     2025-01-26        53              8
# 7   Super Absorbent Pads     2025-02-03        50             17
# 8    Organic Cotton Pads     2025-02-09       187            166
# 9   Super Absorbent Pads     2025-02-11        66              2
# 10          Regular Pads     2025-02-17       123             23
# 11        Overnight Pads     2025-02-23        81             23
# 12          Regular Pads     2025-03-16       115             43
# ...

# %%
plt.plot(df['Quantity'].cumsum(),df['Quantity Used'].cumsum())
plt.xticks(rotation = 20)
plt.plot(df['Quantity'].cumsum(),df['Quantity Left'].cumsum())
